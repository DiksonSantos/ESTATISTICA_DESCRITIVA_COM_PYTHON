# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y = [ 2,5,2,7,5,1]

x = ['N1','N2','N3','N4','N5','N6']

X2 = ['VARIAVEL_Um','VARIAVEL_Dois','VARIAVEL_Três','VARIAVEL_Quatro','VARIAVEL_Cinco','VARIAVEL_Seis']

# %%
#Label -> Usara o Nome de acordo com a Lista Apontada
#Radius -> Define o Tamanho do Desenho
plt.pie(y, labels=x, radius=2)
plt.show()
